-- %% [markdown]
-- # Sales Notebook
--
-- Selecting sales

-- %%
SELECT TOP (100) * FROM Fact.Sale;
-- Out:
-- (100 rows affected)
-- Total execution time: 00:00:00.051
-- <table><tr><th>Sale Key</th><th>City Key</th><th>Customer Key</th><th>Bill To Customer Key</th><th>Stock Item Key</th><th>Invoice Date Key</th><th>Delivery Date Key</th><th>Salesperson Key</th><th>WWI Invoice ID</th><th>Description</th><th>Package</th><th>Quantity</th><th>Unit Price</th><th>Tax Rate</th><th>Total Excluding Tax</th><th>Tax Amount</th><th>Profit</th><th>Total Including Tax</th><th>Total Dry Items</th><th>Total Chiller Items</th><th>Lineage Key</th></tr><tr><td>438</td><td>41568</td><td>0</td><td>0</td><td>176</td><td>2013-01-03</td><td>2013-01-04</td><td>9</td><td>187</td><td>Developer joke mug - there are 10 types of people in the world (White)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>692</td><td>50969</td><td>0</td><td>0</td><td>163</td><td>2013-01-05</td><td>2013-01-06</td><td>11</td><td>282</td><td>IT joke mug - hardware: part of the computer that can be kicked (Black)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>999</td><td>53636</td><td>0</td><td>0</td><td>182</td><td>2013-01-07</td><td>2013-01-08</td><td>12</td><td>388</td><td>Developer joke mug - inheritance is the OO way to become wealthy (White)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>1019</td><td>41165</td><td>0</td><td>0</td><td>197</td><td>2013-01-07</td><td>2013-01-08</td><td>23</td><td>393</td><td>DBA joke mug - it depends (Black)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>1047</td><td>72156</td><td>0</td><td>0</td><td>176</td><td>2013-01-07</td><td>2013-01-08</td><td>6</td><td>401</td><td>Developer joke mug - there are 10 types of people in the world (White)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>1373</td><td>47741</td><td>0</td><td>0</td><td>182</td><td>2013-01-09</td><td>2013-01-10</td><td>7</td><td>498</td><td>Developer joke mug - inheritance is the OO way to become wealthy (White)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>1933</td><td>51415</td><td>0</td><td>0</td><td>198</td><td>2013-01-11</td><td>2013-01-12</td><td>23</td><td>660</td><td>DBA joke mug - it depends (White)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>2024</td><td>68127</td><td>0</td><td>0</td><td>166</td><td>2013-01-12</td><td>2013-01-13</td><td>27</td><td>686</td><td>IT joke mug - that behavior is by design (White)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>2186</td><td>43128</td><td>0</td><td>0</td><td>173</td><td>2013-01-14</td><td>2013-01-15</td><td>21</td><td>732</td><td>Developer joke mug - a foo walks into a bar (Black)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>2209</td><td>47741</td><td>0</td><td>0</td><td>178</td><td>2013-01-14</td><td>2013-01-15</td><td>15</td><td>740</td><td>Developer joke mug - understanding recursion requires understanding recursion (White)</td><td>Each</td><td>3</td><td>13.00</td><td>15.000</td><td>39.00</td><td>5.85</td><td>25.50</td><td>44.85</td><td>3</td><td>0</td><td>11</td></tr><tr><td>2214</td><td>70334</td><td>0</td><td>0</td><td>167</td><td>2013-01-14</td><td>2013-01-15</td><td>27</td><td>741</td><td>IT joke mug - keyboard not found … press  ...

-- %% [markdown]
-- Creating a View

-- %%
IF EXISTS (SELECT 1 FROM sys.views WHERE name = 'V_CustomerSales') 
DROP VIEW dbo.V_CustomerSales;
GO
CREATE VIEW dbo.V_CustomerSales AS (
SELECT C.[Customer]
, S.[Invoice Date Key] AS [Sale Date]
, SUM(S.[Total Including Tax]) AS [Total Daily Sales]
FROM Dimension.Customer C
INNER JOIN Fact.Sale S On S.[Customer Key] = C.[Customer Key]
GROUP BY C.[Customer]
, S.[Invoice Date Key]
);
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.024

-- %% [markdown]
-- Use the new view

-- %%
SELECT [Customer]
, SUM ([Total Daily Sales]) AS [Lifetime Sales]
FROM DBO.V_CustomerSales
WHERE [Customer] <> 'unknown'
GROUP BY [Customer]
HAVING SUM ([TOTAL DAILY SALES]) > 400000;
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.054
-- <table><tr><th>Customer</th><th>Lifetime Sales</th></tr><tr><td>Tailspin Toys (Minidoka, ID)</td><td>427445.57</td></tr><tr><td>Tailspin Toys (Inguadona, MN)</td><td>438689.81</td></tr><tr><td>Wingtip Toys (Grabill, IN)</td><td>403635.05</td></tr><tr><td>Wingtip Toys (San Jacinto, CA)</td><td>408524.95</td></tr><tr><td>Wingtip Toys (Sarversville, PA)</td><td>420001.08</td></tr><tr><td>Wingtip Toys (Morrison Bluff, AR)</td><td>404945.65</td></tr><tr><td>Tailspin Toys (Long Meadow, MD)</td><td>414934.18</td></tr><tr><td>Wingtip Toys (Cuyamungue, NM)</td><td>405824.67</td></tr></table>
